# %% [markdown]
# ## I2DS - Project (Questions)
#
# Nov. 24, 2022

# %% [markdown]
# ## Import the necessary libraries

# %% [markdown]
# Download "DM_student_dataset_2019.csv" file from the Canvas Files section and apply following tasks.

# %% [markdown]
# ## 1) (10 points) Import the dataset.

# %%
# Out:
#     Gender      Education  Age  Weight  Height
# 0   Female       Graduate   28      47     160
# 1     Male       Graduate   27      66     169
# 2     Male  Undergraduate   23      68     172
# 3     Male  Undergraduate   23      88     179
# 4     Male       Graduate   31      85     184
# 5     Male       Graduate   22      63     168
# 6     Male  Undergraduate   24      78     175
# 7     Male  Undergraduate   23      96     192
# 8     Male  Undergraduate   24      80     186
# 9     Male  Undergraduate   23      62     175
# 10    Male       Graduate   26      70     183
# 11    Male       Graduate   26      55     166
# 12    Male  Undergraduate   22      83     185
# 13  Female       Graduate   24      56     165
# 14    Male  Undergraduate   22      81     183
# 15    Male       Graduate   35      90     176
# 16  Female       Graduate   22      57     163
# 17    Male       Graduate   46      86     175
# 18  Female       Graduate   23      60     160
# ...

# %% [markdown]
# ## 2) (10 points) Dataset information
# * Show the size of the dataset.
# * Show the shape of the dataset.
# * Print the # of attributes and # of tuples.
# * Show the attribute names (columns).
# * Show the first 4 rows of the dataset.
# * Show the last 4 rows of the dataset.

# %%
# Show the size of the dataset.
# Out:
# 125

# %%
# Show the shape of the dataset.
# Out:
# (25, 5)

# %%
# Print the # of attributes and # of tuples.
# Out:
# Number of tuples (samples): 25
# Number of attributes (features): 5

# %%
# Show the attribute names.
# Out:
# Index(['Gender', 'Education', 'Age', 'Weight', 'Height'], dtype='object')

# %%
# Show the first 4 rows of the dataset.
# Out:
#    Gender      Education  Age  Weight  Height
# 0  Female       Graduate   28      47     160
# 1    Male       Graduate   27      66     169
# 2    Male  Undergraduate   23      68     172
# 3    Male  Undergraduate   23      88     179

# %%
# Show the last 4 rows of the dataset.
# Out:
#    Gender      Education  Age  Weight  Height
# 21   Male  Undergraduate   24     102     181
# 22   Male  Undergraduate   22      83     179
# 23   Male  Undergraduate   23      76     182
# 24   Male  Undergraduate   23      70     178

# %% [markdown]
# ## 3) (10 points) Generate descriptive statistics that summarize the dataset (for Age, Weight and Height). Use only one line statement!

# %%
# Summarize the dataset
# Out:
#              Age      Weight      Height
# count  25.000000   25.000000   25.000000
# mean   25.320000   74.120000  175.440000
# std     5.289297   14.394212    8.921323
# min    22.000000   47.000000  160.000000
# 25%    23.000000   62.000000  168.000000
# 50%    23.000000   76.000000  176.000000
# 75%    26.000000   85.000000  183.000000
# max    46.000000  102.000000  192.000000

# %% [markdown]
# ## 4) (10 points) Show only "Age", "Weight", "Height" and "Gender" columns of this dataset (Drop the "Education" column).

# %%
# Out:
#     Age  Weight  Height  Gender
# 0    28      47     160  Female
# 1    27      66     169    Male
# 2    23      68     172    Male
# 3    23      88     179    Male
# 4    31      85     184    Male
# 5    22      63     168    Male
# 6    24      78     175    Male
# 7    23      96     192    Male
# 8    24      80     186    Male
# 9    23      62     175    Male
# 10   26      70     183    Male
# 11   26      55     166    Male
# 12   22      83     185    Male
# 13   24      56     165  Female
# 14   22      81     183    Male
# 15   35      90     176    Male
# 16   22      57     163  Female
# 17   46      86     175    Male
# 18   23      60     160  Female
# 19   23      90     185    Male
# 20   24      61     165  Female
# 21   24     102     181    Male
# 22   22      83     179    Male
# 23   23      76     182    Male
# 24   23      70     178    Male

# %% [markdown]
# ## 5) (10 points) Show dataset separately for *Female* and *Male* students.

# %%
# Out:
#     Gender Education  Age  Weight  Height
# 0   Female  Graduate   28      47     160
# 13  Female  Graduate   24      56     165
# 16  Female  Graduate   22      57     163
# 18  Female  Graduate   23      60     160
# 20  Female  Graduate   24      61     165

# %%
# Out:
#    Gender      Education  Age  Weight  Height
# 1    Male       Graduate   27      66     169
# 2    Male  Undergraduate   23      68     172
# 3    Male  Undergraduate   23      88     179
# 4    Male       Graduate   31      85     184
# 5    Male       Graduate   22      63     168
# 6    Male  Undergraduate   24      78     175
# 7    Male  Undergraduate   23      96     192
# 8    Male  Undergraduate   24      80     186
# 9    Male  Undergraduate   23      62     175
# 10   Male       Graduate   26      70     183
# 11   Male       Graduate   26      55     166
# 12   Male  Undergraduate   22      83     185
# 14   Male  Undergraduate   22      81     183
# 15   Male       Graduate   35      90     176
# 17   Male       Graduate   46      86     175
# 19   Male  Undergraduate   23      90     185
# 21   Male  Undergraduate   24     102     181
# 22   Male  Undergraduate   22      83     179
# 23   Male  Undergraduate   23      76     182
# ...

# %% [markdown]
# ## 6) (10 points) Print average values for *Female* and *Male* students separately.

# %%
# Out:
# Average age of female students: 24.2
# Average age of male students: 25.6
# Average weight of female students: 56.2
# Average weight of male students: 78.6
# Average height of female students: 162.6
# Average height of male students: 178.65

# %% [markdown]
# ## 7) (40 points) Visualize the data
#
# * **Bar plot:**
# Show the gender distribution and education distribution separately.
# * **Box plot:**
# Show the dataset using attributes *Age*, *Weight* and *Height* for Female and Male students separately.
# * **Scatter plot:**
# Show the dataset using attributes *Weight* and *Height* according to class label *Gender*. Use different colors for *Gender* on the plot.
#
# * **Histogram**

# %% [markdown]
# ### Bar plot

# %%
# Bar plot representation of the gender distribution

# %%
# Bar plot representation of the education distribution

# %% [markdown]
# ### Box plot

# %%
# Out:
# (0.0, 200.0)

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# ### Histogram
